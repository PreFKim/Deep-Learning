# %% [markdown]
# 라이브러리 , 마운트
# ================================

# %%
import tensorflow as tf
import keras
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os,cv2,glob,shutil
from tqdm import tqdm #진행률 표시

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 기본 데이터 정의
# ============

# %%
SEED = 909

#배치사이즈
BATCH_SIZE = 16

#에폭의 수
NUM_OF_EPOCHS = 25

#Train,Valid 비율
validation_ratio=0.2

#원래(480,720) (이미지의 특징이 사라지지 않는 선에서 수정해도 상관없음) 
#원래(540,960)
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
IMG_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)

#데이터의 경로 설정
data_dir = '/content/drive/MyDrive/newstudy/ocean_trash_classfication'
data_dir_train = os.path.join(data_dir, 'train/images')
data_dir_test = os.path.join(data_dir, 'test/images')

class_name = sorted(os.listdir(data_dir_train))

print(class_name)
# Out:
# ['bundle of ropes', 'circular fish trap', 'eel fish trap', 'fish net', 'other objects', 'rectangular fish trap', 'rope', 'spring fish trap', 'tire', 'wood']

# %% [markdown]
# 출력함수
# ==============================

# %%
def predict_img(img,get_last=False): 
  prediction = model.predict(np.expand_dims(img, axis=0)) #h,w,class

  if type(model.output) == list:
    num_of_output = len(model.output)
    x = prediction[num_of_output-1] if get_last else sum(prediction) / num_of_output
  else:
    x = prediction

  x = np.argmax(x[0], axis=-1) #해당픽셀의 채널 중에서 가장 큰 인덱스 값 가져옴 h,w

  return x

def display_dataset(ds,num=1,predict=False,test=False):
  i=0
  for x, y in ds:
    if i== num:
      break;

    dx = x[0]*255
    dx = dx.numpy()
    dy = np.argmax(y[0])
    print(dy,y[0])

    c = 'True:'
    if test:
      c += 'No Named'
    else:
      c += class_name[dy]

    if predict:
      c += ',Predict:' + class_name[predict_img(x[0])]

    plt.title(c)
    plt.imshow(tf.keras.preprocessing.image.array_to_img(dx))
    plt.show()
    i+=1

def display_test(img,num=1):
  for i in range(num):
    x = read_image(img[i])
    dx = x*255
    p = predict_img(x)
    plt.title(class_name[p])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(dx))
    plt.show()

#model 학습 정보 표시,저장
def display_history(history, dir, num,save_pic=True,save_csv=True,save_best_infor=True):
  t = ['Accuracy','Loss']
  k = ['accuracy','loss']
  p = ['lower','upper']


  if type(model.output) != list : num_of_output = 1
  else: num_of_output = len(model.output)

  plt.figure(figsize=(24,3*num_of_output))

  for i in range(num_of_output):

    if type(model.output) != list : name = ''
    else: name = model.output_names[i]+'_'

    for j in range(4):
      plt.subplot(num_of_output,4,i*4+j+1)
      if j%2==0 :
        plt.plot(history[f'{name}{k[j//2]}'], 'g-', label= k[j//2])
        if i==0:
          plt.title(t[j//2])
      else :
        plt.plot(history[f'val_{name}{k[j//2]}'], 'g-', label= 'val_'+k[j//2])
        if i==0:
          plt.title('Val_'+t[j//2])
      if j==0:
        plt.ylabel(f'Output[{i}]')
      elif i== num_of_output-1 :
        plt.xlabel('Epoch')
      plt.legend(loc= p[j//2]+' right')
      plt.grid(True, axis='both',alpha=0.5)

  if (save_pic) : 
    plt.savefig(f'{dir}/Graph{num}.png')

  if (save_csv):
    hist_df = pd.DataFrame(history) 
    with open(f'{dir}/History{num}.csv', mode='w') as f:
      hist_df.to_csv(f)

  if (save_best_infor):
    idx = np.argmin(history['val_loss'])
    result = [['Epoch'],[idx+1]]
    start_idx = 1-(type(history) == dict)
    for i in range(start_idx,len(history.keys())):
      key = list(history.keys())[i]
      result[0].append(key)
      result[1].append(history[key][idx])
    hist_df = pd.DataFrame(result) 
    with open(f'{dir}/Best{num}.Infor.csv', mode='w') as f:
      hist_df.to_csv(f)
      
  plt.show()

# %% [markdown]
# 데이터 전처리
# ====================

# %%
def read_image(x):
  x = cv2.imread(x, cv2.IMREAD_COLOR)
  x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB) 
  x = cv2.resize(x, (IMAGE_WIDTH,IMAGE_HEIGHT))
  x = x / 255.0
  x = x.astype(np.float32)
  return x


def tf_dataset(x,y, batch_size=1):
  dataset = tf.data.Dataset.from_tensor_slices((x,y))
  dataset = dataset.shuffle(buffer_size=1000)
  dataset = dataset.map(preprocess,num_parallel_calls=tf.data.experimental.AUTOTUNE)
  dataset = dataset.batch(batch_size)
  dataset = dataset.repeat()
  dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return dataset

def preprocess(x,y):
  def f(x,y):
      image = x.decode()
      image = read_image(image)
      label = y
      return image, label

  image, label = tf.numpy_function(f, [x,y], [tf.float32, tf.int32])
  label = tf.one_hot(label, len(class_name), dtype=tf.int32)
  image.set_shape([IMAGE_HEIGHT, IMAGE_WIDTH, 3])
  label.set_shape(len(class_name))
  print(image.shape,label.shape)
  return image, label

train_x = sorted(glob.glob(os.path.join(data_dir_train, '*/*')))
train_y = [class_name.index(train_x[i].split('/')[-2]) for i in range(len(train_x)) ]


#print(train_x)
#print(train_y)

test = sorted(glob.glob(os.path.join(data_dir_test,'*')))

train_x, valid_x = train_test_split(train_x, test_size=validation_ratio, random_state=SEED)
train_y, valid_y = train_test_split(train_y, test_size=validation_ratio, random_state=SEED)

print(f"Dataset: Train: {len(train_x)} - Valid: {len(valid_x)} - Test: {len(test)}")

train_dataset = tf_dataset(train_x,train_y, batch_size=BATCH_SIZE)
valid_dataset = tf_dataset(valid_x,valid_y, batch_size=BATCH_SIZE)

# %%
NUM_TRAIN = len(train_x)

NUM_VALID = len(valid_x)

EPOCH_STEP_TRAIN = NUM_TRAIN // BATCH_SIZE
EPOCH_STEP_VALID = NUM_VALID // BATCH_SIZE

# %%
display_dataset(train_dataset,10,False)

# %% [markdown]
# ResNet50 모델
# ======================

# %%
def conv(input,chennel,kernel_sizes,strides=2,padding='valid',is_relu=True,is_bn=True):
  x = input
  x = keras.layers.Conv2D(chennel,kernel_sizes,strides,padding=padding)(x)
  if is_bn:
    x = keras.layers.BatchNormalization()(x)
  if is_relu:
    x = keras.activations.relu(x)
  return x

def resnet50(classes=1000,initial_features=64):
  inputs = keras.Input(shape=[IMAGE_HEIGHT,IMAGE_WIDTH,3])
  x= inputs

  x = conv(x,initial_features,7,2,'same')
  x = keras.layers.MaxPool2D(3,2,'same')(x)

  repeat = [3,4,6,3]
  for i in range(4):
    for j in range(repeat[i]):
      if j==0:  #conv
        if i==0: 
          strides = 1
        else :
          strides = 2
        shortcut = conv(x,initial_features*2**(i+2),1,strides,'valid',False)
      else:
        shortcut = x
        strides = 1
        
      x = conv(x,initial_features*2**i,1,strides,'valid')
      x = conv(x,initial_features*2**i,3,1,'same')
      x = conv(x,initial_features*2**(i+2),1,1,'valid',False)
      x = keras.layers.add([x,shortcut])
      x = keras.activations.relu(x)
  
  x = keras.layers.GlobalAveragePool2D()(x)
  x = keras.layers.Dense(classes,activation='softmax')(x)

  return keras.Model(inputs=[inputs], outputs=[x], name=f'ResNet50-F{initial_features}-C{classes}')

model = resnet50(len(class_name))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "ResNet50-F64-C10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_41 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_1663 (Conv2D)           (None, 109, 109, 64  9472        ['input_41[0][0]']
#                                 )
#
#  batch_normalization_1663 (Batc  (None, 109, 109, 64  256        ['conv2d_1663[0][0]']
#  hNormalization)                )
#
#  tf.nn.relu_1524 (TFOpLambda)   (None, 109, 109, 64  0           ['batch_normalization_1663[0][0]'
#                                 )                                ]
#
#  max_pooling2d_39 (MaxPooling2D  (None, 55, 55, 64)  0           ['tf.nn.relu_1524[0][0]']
#  )
#
#  conv2d_1665 (Conv2D)           (None, 55, 55, 64)   4160        ['max_pooling2d_39[0][0]']
#
#  batch_normalization_1665 (Batc  (None, 55, 55, 64)  256         ['conv2d_1665[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1525 (TFOpLambda)   (None, 55, 55, 64)   0           ['batch_normalization_1665[0][0]'
#                                                                  ]
#
#  conv2d_1666 (Conv2D)           (None, 55, 55, 64)   36928       ['tf.nn.relu_1525[0][0]']
#
#  batch_normalization_1666 (Batc  (None, 55, 55, 64)  256         ['conv2d_1666[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1526 (TFOpLambda)   (None, 55, 55, 64)   0           ['batch_normalization_1666[0][0]'
#                                                                  ]
#
#  conv2d_1667 (Conv2D)           (None, 55, 55, 256)  16640       ['tf.nn.relu_1526[0][0]']
#
#  conv2d_1664 (Conv2D)           (None, 55, 55, 256)  16640       ['max_pooling2d_39[0][0]']
#
#  batch_normalization_1667 (Batc  (None, 55, 55, 256)  1024       ['conv2d_1667[0][0]']
#  hNormalization)
#
#  batch_normalization_1664 (Batc  (None, 55, 55, 256)  1024       ['conv2d_1664[0][0]']
#  hNormalization)
#
#  add_497 (Add)                  (None, 55, 55, 256)  0           ['batch_normalization_1667[0][0]'
#                                                                  , 'batch_normalization_1664[0][0]
#                                                                  ']
#
#  tf.nn.relu_1527 (TFOpLambda)   (None, 55, 55, 256)  0           ['add_497[0][0]']
#
#  conv2d_1668 (Conv2D)           (None, 55, 55, 64)   16448       ['tf.nn.relu_1527[0][0]']
#
#  batch_normalization_1668 (Batc  (None, 55, 55, 64)  256         ['conv2d_1668[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1528 (TFOpLambda)   (None, 55, 55, 64)   0           ['batch_normalization_1668[0][0]'
#                                                                  ]
#
#  conv2d_1669 (Conv2D)           (None, 55, 55, 64)   36928       ['tf.nn.relu_1528[0][0]']
#
#  batch_normalization_1669 (Batc  (None, 55, 55, 64)  256         ['conv2d_1669[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1529 (TFOpLambda)   (None, 55, 55, 64)   0           ['batch_normalization_1669[0][0]'
#                                                                  ]
#
#  conv2d_1670 (Conv2D)           (None, 55, 55, 256)  16640       ['tf.nn.relu_1529[0][0]']
#
#  batch_normalization_1670 (Batc  (None, 55, 55, 256)  1024       ['conv2d_1670[0][0]']
#  hNormalization)
#
#  add_498 (Add)                  (None, 55, 55, 256)  0           ['batch_normalization_1670[0][0]'
#                                                                  , 'tf.nn.relu_1527[0][0]']
#
#  tf.nn.relu_1530 (TFOpLambda)   (None, 55, 55, 256)  0           ['add_498[0][0]']
#
#  conv2d_1671 (Conv2D)           (None, 55, 55, 64)   16448       ['tf.nn.relu_1530[0][0]']
#
#  batch_normalization_1671 (Batc  (None, 55, 55, 64)  256         ['conv2d_1671[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1531 (TFOpLambda)   (None, 55, 55, 64)   0           ['batch_normalization_1671[0][0]'
#                                                                  ]
#
#  conv2d_1672 (Conv2D)           (None, 55, 55, 64)   36928       ['tf.nn.relu_1531[0][0]']
#
#  batch_normalization_1672 (Batc  (None, 55, 55, 64)  256         ['conv2d_1672[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1532 (TFOpLambda)   (None, 55, 55, 64)   0           ['batch_normalization_1672[0][0]'
#                                                                  ]
#
#  conv2d_1673 (Conv2D)           (None, 55, 55, 256)  16640       ['tf.nn.relu_1532[0][0]']
#
#  batch_normalization_1673 (Batc  (None, 55, 55, 256)  1024       ['conv2d_1673[0][0]']
#  hNormalization)
#
#  add_499 (Add)                  (None, 55, 55, 256)  0           ['batch_normalization_1673[0][0]'
#                                                                  , 'tf.nn.relu_1530[0][0]']
#
#  tf.nn.relu_1533 (TFOpLambda)   (None, 55, 55, 256)  0           ['add_499[0][0]']
#
#  conv2d_1675 (Conv2D)           (None, 28, 28, 128)  32896       ['tf.nn.relu_1533[0][0]']
#
#  batch_normalization_1675 (Batc  (None, 28, 28, 128)  512        ['conv2d_1675[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1534 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1675[0][0]'
#                                                                  ]
#
#  conv2d_1676 (Conv2D)           (None, 28, 28, 128)  147584      ['tf.nn.relu_1534[0][0]']
#
#  batch_normalization_1676 (Batc  (None, 28, 28, 128)  512        ['conv2d_1676[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1535 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1676[0][0]'
#                                                                  ]
#
#  conv2d_1677 (Conv2D)           (None, 28, 28, 512)  66048       ['tf.nn.relu_1535[0][0]']
#
#  conv2d_1674 (Conv2D)           (None, 28, 28, 512)  131584      ['tf.nn.relu_1533[0][0]']
#
#  batch_normalization_1677 (Batc  (None, 28, 28, 512)  2048       ['conv2d_1677[0][0]']
#  hNormalization)
#
#  batch_normalization_1674 (Batc  (None, 28, 28, 512)  2048       ['conv2d_1674[0][0]']
#  hNormalization)
#
#  add_500 (Add)                  (None, 28, 28, 512)  0           ['batch_normalization_1677[0][0]'
#                                                                  , 'batch_normalization_1674[0][0]
#                                                                  ']
#
#  tf.nn.relu_1536 (TFOpLambda)   (None, 28, 28, 512)  0           ['add_500[0][0]']
#
#  conv2d_1678 (Conv2D)           (None, 28, 28, 128)  65664       ['tf.nn.relu_1536[0][0]']
#
#  batch_normalization_1678 (Batc  (None, 28, 28, 128)  512        ['conv2d_1678[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1537 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1678[0][0]'
#                                                                  ]
#
#  conv2d_1679 (Conv2D)           (None, 28, 28, 128)  147584      ['tf.nn.relu_1537[0][0]']
#
#  batch_normalization_1679 (Batc  (None, 28, 28, 128)  512        ['conv2d_1679[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1538 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1679[0][0]'
#                                                                  ]
#
#  conv2d_1680 (Conv2D)           (None, 28, 28, 512)  66048       ['tf.nn.relu_1538[0][0]']
#
#  batch_normalization_1680 (Batc  (None, 28, 28, 512)  2048       ['conv2d_1680[0][0]']
#  hNormalization)
#
#  add_501 (Add)                  (None, 28, 28, 512)  0           ['batch_normalization_1680[0][0]'
#                                                                  , 'tf.nn.relu_1536[0][0]']
#
#  tf.nn.relu_1539 (TFOpLambda)   (None, 28, 28, 512)  0           ['add_501[0][0]']
#
#  conv2d_1681 (Conv2D)           (None, 28, 28, 128)  65664       ['tf.nn.relu_1539[0][0]']
#
#  batch_normalization_1681 (Batc  (None, 28, 28, 128)  512        ['conv2d_1681[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1540 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1681[0][0]'
#                                                                  ]
#
#  conv2d_1682 (Conv2D)           (None, 28, 28, 128)  147584      ['tf.nn.relu_1540[0][0]']
#
#  batch_normalization_1682 (Batc  (None, 28, 28, 128)  512        ['conv2d_1682[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1541 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1682[0][0]'
#                                                                  ]
#
#  conv2d_1683 (Conv2D)           (None, 28, 28, 512)  66048       ['tf.nn.relu_1541[0][0]']
#
#  batch_normalization_1683 (Batc  (None, 28, 28, 512)  2048       ['conv2d_1683[0][0]']
#  hNormalization)
#
#  add_502 (Add)                  (None, 28, 28, 512)  0           ['batch_normalization_1683[0][0]'
#                                                                  , 'tf.nn.relu_1539[0][0]']
#
#  tf.nn.relu_1542 (TFOpLambda)   (None, 28, 28, 512)  0           ['add_502[0][0]']
#
#  conv2d_1684 (Conv2D)           (None, 28, 28, 128)  65664       ['tf.nn.relu_1542[0][0]']
#
#  batch_normalization_1684 (Batc  (None, 28, 28, 128)  512        ['conv2d_1684[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1543 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1684[0][0]'
#                                                                  ]
#
#  conv2d_1685 (Conv2D)           (None, 28, 28, 128)  147584      ['tf.nn.relu_1543[0][0]']
#
#  batch_normalization_1685 (Batc  (None, 28, 28, 128)  512        ['conv2d_1685[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1544 (TFOpLambda)   (None, 28, 28, 128)  0           ['batch_normalization_1685[0][0]'
#                                                                  ]
#
#  conv2d_1686 (Conv2D)           (None, 28, 28, 512)  66048       ['tf.nn.relu_1544[0][0]']
#
#  batch_normalization_1686 (Batc  (None, 28, 28, 512)  2048       ['conv2d_1686[0][0]']
#  hNormalization)
#
#  add_503 (Add)                  (None, 28, 28, 512)  0           ['batch_normalization_1686[0][0]'
#                                                                  , 'tf.nn.relu_1542[0][0]']
#
#  tf.nn.relu_1545 (TFOpLambda)   (None, 28, 28, 512)  0           ['add_503[0][0]']
#
#  conv2d_1688 (Conv2D)           (None, 14, 14, 256)  131328      ['tf.nn.relu_1545[0][0]']
#
#  batch_normalization_1688 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1688[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1546 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1688[0][0]'
#                                                                  ]
#
#  conv2d_1689 (Conv2D)           (None, 14, 14, 256)  590080      ['tf.nn.relu_1546[0][0]']
#
#  batch_normalization_1689 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1689[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1547 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1689[0][0]'
#                                                                  ]
#
#  conv2d_1690 (Conv2D)           (None, 14, 14, 1024  263168      ['tf.nn.relu_1547[0][0]']
#                                 )
#
#  conv2d_1687 (Conv2D)           (None, 14, 14, 1024  525312      ['tf.nn.relu_1545[0][0]']
#                                 )
#
#  batch_normalization_1690 (Batc  (None, 14, 14, 1024  4096       ['conv2d_1690[0][0]']
#  hNormalization)                )
#
#  batch_normalization_1687 (Batc  (None, 14, 14, 1024  4096       ['conv2d_1687[0][0]']
#  hNormalization)                )
#
#  add_504 (Add)                  (None, 14, 14, 1024  0           ['batch_normalization_1690[0][0]'
#                                 )                                , 'batch_normalization_1687[0][0]
#                                                                  ']
#
#  tf.nn.relu_1548 (TFOpLambda)   (None, 14, 14, 1024  0           ['add_504[0][0]']
#                                 )
#
#  conv2d_1691 (Conv2D)           (None, 14, 14, 256)  262400      ['tf.nn.relu_1548[0][0]']
#
#  batch_normalization_1691 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1691[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1549 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1691[0][0]'
#                                                                  ]
#
#  conv2d_1692 (Conv2D)           (None, 14, 14, 256)  590080      ['tf.nn.relu_1549[0][0]']
#
#  batch_normalization_1692 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1692[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1550 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1692[0][0]'
#                                                                  ]
#
#  conv2d_1693 (Conv2D)           (None, 14, 14, 1024  263168      ['tf.nn.relu_1550[0][0]']
#                                 )
#
#  batch_normalization_1693 (Batc  (None, 14, 14, 1024  4096       ['conv2d_1693[0][0]']
#  hNormalization)                )
#
#  add_505 (Add)                  (None, 14, 14, 1024  0           ['batch_normalization_1693[0][0]'
#                                 )                                , 'tf.nn.relu_1548[0][0]']
#
#  tf.nn.relu_1551 (TFOpLambda)   (None, 14, 14, 1024  0           ['add_505[0][0]']
#                                 )
#
#  conv2d_1694 (Conv2D)           (None, 14, 14, 256)  262400      ['tf.nn.relu_1551[0][0]']
#
#  batch_normalization_1694 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1694[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1552 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1694[0][0]'
#                                                                  ]
#
#  conv2d_1695 (Conv2D)           (None, 14, 14, 256)  590080      ['tf.nn.relu_1552[0][0]']
#
#  batch_normalization_1695 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1695[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1553 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1695[0][0]'
#                                                                  ]
#
#  conv2d_1696 (Conv2D)           (None, 14, 14, 1024  263168      ['tf.nn.relu_1553[0][0]']
#                                 )
#
#  batch_normalization_1696 (Batc  (None, 14, 14, 1024  4096       ['conv2d_1696[0][0]']
#  hNormalization)                )
#
#  add_506 (Add)                  (None, 14, 14, 1024  0           ['batch_normalization_1696[0][0]'
#                                 )                                , 'tf.nn.relu_1551[0][0]']
#
#  tf.nn.relu_1554 (TFOpLambda)   (None, 14, 14, 1024  0           ['add_506[0][0]']
#                                 )
#
#  conv2d_1697 (Conv2D)           (None, 14, 14, 256)  262400      ['tf.nn.relu_1554[0][0]']
#
#  batch_normalization_1697 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1697[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1555 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1697[0][0]'
#                                                                  ]
#
#  conv2d_1698 (Conv2D)           (None, 14, 14, 256)  590080      ['tf.nn.relu_1555[0][0]']
#
#  batch_normalization_1698 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1698[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1556 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1698[0][0]'
#                                                                  ]
#
#  conv2d_1699 (Conv2D)           (None, 14, 14, 1024  263168      ['tf.nn.relu_1556[0][0]']
#                                 )
#
#  batch_normalization_1699 (Batc  (None, 14, 14, 1024  4096       ['conv2d_1699[0][0]']
#  hNormalization)                )
#
#  add_507 (Add)                  (None, 14, 14, 1024  0           ['batch_normalization_1699[0][0]'
#                                 )                                , 'tf.nn.relu_1554[0][0]']
#
#  tf.nn.relu_1557 (TFOpLambda)   (None, 14, 14, 1024  0           ['add_507[0][0]']
#                                 )
#
#  conv2d_1700 (Conv2D)           (None, 14, 14, 256)  262400      ['tf.nn.relu_1557[0][0]']
#
#  batch_normalization_1700 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1700[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1558 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1700[0][0]'
#                                                                  ]
#
#  conv2d_1701 (Conv2D)           (None, 14, 14, 256)  590080      ['tf.nn.relu_1558[0][0]']
#
#  batch_normalization_1701 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1701[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1559 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1701[0][0]'
#                                                                  ]
#
#  conv2d_1702 (Conv2D)           (None, 14, 14, 1024  263168      ['tf.nn.relu_1559[0][0]']
#                                 )
#
#  batch_normalization_1702 (Batc  (None, 14, 14, 1024  4096       ['conv2d_1702[0][0]']
#  hNormalization)                )
#
#  add_508 (Add)                  (None, 14, 14, 1024  0           ['batch_normalization_1702[0][0]'
#                                 )                                , 'tf.nn.relu_1557[0][0]']
#
#  tf.nn.relu_1560 (TFOpLambda)   (None, 14, 14, 1024  0           ['add_508[0][0]']
#                                 )
#
#  conv2d_1703 (Conv2D)           (None, 14, 14, 256)  262400      ['tf.nn.relu_1560[0][0]']
#
#  batch_normalization_1703 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1703[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1561 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1703[0][0]'
#                                                                  ]
#
#  conv2d_1704 (Conv2D)           (None, 14, 14, 256)  590080      ['tf.nn.relu_1561[0][0]']
#
#  batch_normalization_1704 (Batc  (None, 14, 14, 256)  1024       ['conv2d_1704[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1562 (TFOpLambda)   (None, 14, 14, 256)  0           ['batch_normalization_1704[0][0]'
#                                                                  ]
#
#  conv2d_1705 (Conv2D)           (None, 14, 14, 1024  263168      ['tf.nn.relu_1562[0][0]']
#                                 )
#
#  batch_normalization_1705 (Batc  (None, 14, 14, 1024  4096       ['conv2d_1705[0][0]']
#  hNormalization)                )
#
#  add_509 (Add)                  (None, 14, 14, 1024  0           ['batch_normalization_1705[0][0]'
#                                 )                                , 'tf.nn.relu_1560[0][0]']
#
#  tf.nn.relu_1563 (TFOpLambda)   (None, 14, 14, 1024  0           ['add_509[0][0]']
#                                 )
#
#  conv2d_1707 (Conv2D)           (None, 7, 7, 512)    524800      ['tf.nn.relu_1563[0][0]']
#
#  batch_normalization_1707 (Batc  (None, 7, 7, 512)   2048        ['conv2d_1707[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1564 (TFOpLambda)   (None, 7, 7, 512)    0           ['batch_normalization_1707[0][0]'
#                                                                  ]
#
#  conv2d_1708 (Conv2D)           (None, 7, 7, 512)    2359808     ['tf.nn.relu_1564[0][0]']
#
#  batch_normalization_1708 (Batc  (None, 7, 7, 512)   2048        ['conv2d_1708[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1565 (TFOpLambda)   (None, 7, 7, 512)    0           ['batch_normalization_1708[0][0]'
#                                                                  ]
#
#  conv2d_1709 (Conv2D)           (None, 7, 7, 2048)   1050624     ['tf.nn.relu_1565[0][0]']
#
#  conv2d_1706 (Conv2D)           (None, 7, 7, 2048)   2099200     ['tf.nn.relu_1563[0][0]']
#
#  batch_normalization_1709 (Batc  (None, 7, 7, 2048)  8192        ['conv2d_1709[0][0]']
#  hNormalization)
#
#  batch_normalization_1706 (Batc  (None, 7, 7, 2048)  8192        ['conv2d_1706[0][0]']
#  hNormalization)
#
#  add_510 (Add)                  (None, 7, 7, 2048)   0           ['batch_normalization_1709[0][0]'
#                                                                  , 'batch_normalization_1706[0][0]
#                                                                  ']
#
#  tf.nn.relu_1566 (TFOpLambda)   (None, 7, 7, 2048)   0           ['add_510[0][0]']
#
#  conv2d_1710 (Conv2D)           (None, 7, 7, 512)    1049088     ['tf.nn.relu_1566[0][0]']
#
#  batch_normalization_1710 (Batc  (None, 7, 7, 512)   2048        ['conv2d_1710[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1567 (TFOpLambda)   (None, 7, 7, 512)    0           ['batch_normalization_1710[0][0]'
#                                                                  ]
#
#  conv2d_1711 (Conv2D)           (None, 7, 7, 512)    2359808     ['tf.nn.relu_1567[0][0]']
#
#  batch_normalization_1711 (Batc  (None, 7, 7, 512)   2048        ['conv2d_1711[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1568 (TFOpLambda)   (None, 7, 7, 512)    0           ['batch_normalization_1711[0][0]'
#                                                                  ]
#
#  conv2d_1712 (Conv2D)           (None, 7, 7, 2048)   1050624     ['tf.nn.relu_1568[0][0]']
#
#  batch_normalization_1712 (Batc  (None, 7, 7, 2048)  8192        ['conv2d_1712[0][0]']
#  hNormalization)
#
#  add_511 (Add)                  (None, 7, 7, 2048)   0           ['batch_normalization_1712[0][0]'
#                                                                  , 'tf.nn.relu_1566[0][0]']
#
#  tf.nn.relu_1569 (TFOpLambda)   (None, 7, 7, 2048)   0           ['add_511[0][0]']
#
#  conv2d_1713 (Conv2D)           (None, 7, 7, 512)    1049088     ['tf.nn.relu_1569[0][0]']
#
#  batch_normalization_1713 (Batc  (None, 7, 7, 512)   2048        ['conv2d_1713[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1570 (TFOpLambda)   (None, 7, 7, 512)    0           ['batch_normalization_1713[0][0]'
#                                                                  ]
#
#  conv2d_1714 (Conv2D)           (None, 7, 7, 512)    2359808     ['tf.nn.relu_1570[0][0]']
#
#  batch_normalization_1714 (Batc  (None, 7, 7, 512)   2048        ['conv2d_1714[0][0]']
#  hNormalization)
#
#  tf.nn.relu_1571 (TFOpLambda)   (None, 7, 7, 512)    0           ['batch_normalization_1714[0][0]'
#                                                                  ]
#
#  conv2d_1715 (Conv2D)           (None, 7, 7, 2048)   1050624     ['tf.nn.relu_1571[0][0]']
#
#  batch_normalization_1715 (Batc  (None, 7, 7, 2048)  8192        ['conv2d_1715[0][0]']
#  hNormalization)
#
#  add_512 (Add)                  (None, 7, 7, 2048)   0           ['batch_normalization_1715[0][0]'
#                                                                  , 'tf.nn.relu_1569[0][0]']
#
#  tf.nn.relu_1572 (TFOpLambda)   (None, 7, 7, 2048)   0           ['add_512[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 2048)        0           ['tf.nn.relu_1572[0][0]']
#  obalAveragePooling2D)
#
#  dense_46 (Dense)               (None, 10)           20490       ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# 학습
# ================

# %%
#학습부분
print(f'Train Data:{NUM_TRAIN}')
print(f'Valid Data:{NUM_VALID}')
print(f'Epochs:{NUM_OF_EPOCHS}')
print(f'Batch Size:{BATCH_SIZE}')
print(f'Num Class:{len(class_name)}')
print(f'Model Name:{model.name}')
print(f'Loss:{model.loss}')
print(f'Dataset Name:{data_dir.split("/")[-1]}')
print(f'I/O Image Size (H * W):{IMAGE_HEIGHT} * {IMAGE_WIDTH}')

cp_dir = f'{data_dir}/{model.name}.h5'

mc = tf.keras.callbacks.ModelCheckpoint(filepath=cp_dir, 
                                        save_best_only=True,
                                        verbose=1
                                        )

history = model.fit(train_dataset,
                    steps_per_epoch=EPOCH_STEP_TRAIN,
                    validation_data=valid_dataset,
                    validation_steps=EPOCH_STEP_VALID,
                    epochs=NUM_OF_EPOCHS,
                    callbacks=[mc]
                    )

# %%
save_dir = f'{data_dir}/model/{model.name}-H{IMAGE_HEIGHT}-W{IMAGE_WIDTH}-{BATCH_SIZE}-globalavgpool'

if os.path.exists(save_dir) == False:
  os.makedirs(save_dir)

new_model_num = 1
while (os.path.exists(f'{save_dir}/Model{new_model_num}.h5')):
  new_model_num += 1

model.save(f'{save_dir}/Model{new_model_num}.h5')
if os.path.exists(cp_dir):
  shutil.move(cp_dir,f'{save_dir}/Best{new_model_num}.h5')
display_history(history.history,save_dir,new_model_num,True,True,True)

# %%
display_test(test,len(test))

# %%
display_dataset(train_dataset,100,True)

# %% [markdown]
# 모델 불러오기
# ===========================

# %%
# 이전에 컴파일 한 모델 불러오기
load_dir = f'{data_dir}/model/ResNet50-F64-C10-H224-W224-16-globalavgpool'
model_num = 1

sel_best = False
model_name = ''

if sel_best == True: 
  model_name = 'Best' 
else :
  model_name = 'Model'


if os.path.exists(f'{load_dir}/{model_name}{model_num}.h5'):
  model = tf.keras.models.load_model(f'{load_dir}/{model_name}{model_num}.h5')
else :
  print('모델이 없습니다.')

if os.path.exists(f'{load_dir}/History{model_num}.csv'):
  history = pd.read_csv(f'{load_dir}/History{model_num}.csv')
  display_history(history,load_dir,model_num,True,False,True) 
else :
  print("학습과정에 대한 정보가 없습니다.")
